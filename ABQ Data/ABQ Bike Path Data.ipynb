# %%
import requests
import json
import pandas as pd

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/fullviewer/MapServer/19/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

bike_list = response.json()['features']
bikes = pd.json_normalize(bike_list)
bikes.columns = bikes.columns.str.lstrip("attributes.")

# %%
bikes
# Out:
#      OBJECTID                  PathType         ParentPathName    Status  \
# 0     3485923  Paved Multiple Use Trail           I-40 Trail N  Existing
# 1     3485924  Paved Multiple Use Trail           Harper Trail  Existing
# 2     3485925  Paved Multiple Use Trail  Amole del Norte Trail  Existing
# 3     3485926  Paved Multiple Use Trail  Amole del Norte Trail  Existing
# 4     3485927  Paved Multiple Use Trail  Amole del Norte Trail  Existing
# ..        ...                       ...                    ...       ...
# 995   3486918                  Crossing       BNSF RR Crossing  Existing
# 996   3486919       NMDOT Bike Facility       Paseo del Norte   Existing
# 997   3486920  Paved Multiple Use Trail          Alameda Trail  Existing
# 998   3486921  Paved Multiple Use Trail          Alameda Trail  Existing
# 999   3486922  Paved Multiple Use Trail            Intel Trail  Existing
#
#     MaintainedBy  Shape_Length  \
# 0          NMDOT    265.937800
# ...
