# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/ParkingCitationLocations/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

parking_citation_list = response.json()['features']
parking_citations = pd.json_normalize(parking_citation_list)
parking_citations.columns = parking_citations.columns.str.lstrip("attributes.")

# %%
parking_citations
# Out:
#       OBJECTID       CitationNum      IssueDate     IssueTime  \
# 0    252037033  C254786           1500163200000 -2.209160e+12
# 1    252037034              None  1435795200000 -2.209121e+12
# 2    252037035        W001201058  1500336000000 -2.209113e+12
# 3    252037036  C273676           1499904000000 -2.209089e+12
# 4    252037037        W001201038  1500336000000 -2.209118e+12
# ..         ...               ...            ...           ...
# 995  252038028        W001189823  1487289600000 -2.209113e+12
# 996  252038029        W001190359  1487203200000 -2.209100e+12
# 997  252038030        W001190319  1487203200000 -2.209119e+12
# 998  252038031        W001190324  1487203200000 -2.209117e+12
# 999  252038032        W001190308  1487203200000 -2.209123e+12
#
#                        Street_Location  \
# 0    2400 SUNPORT BLVD SE ABQ NM 87106
# 1                       229 GEN ARNOLD
# 2                    300 CENTRAL AV SW
# 3            ANANHEIM AV NE/SAN TESORO
# ...
