# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/Route66NeonSigns/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

sign_list = response.json()['features']
signs = pd.json_normalize(sign_list)
signs.columns = signs.columns.str.lstrip("attributes.")

# %%
signs
# Out:
#      OBJECTID       SIGNTYPE     geometry.x    geometry.y
# 0           1  HISTORIC NEON -11872599.0786  4175449.8226
# 1           2  HISTORIC NEON -11872808.6317  4175483.3818
# 2           3  HISTORIC NEON -11875129.2801  4176970.1822
# 3           4  HISTORIC NEON -11875233.9262  4176897.0504
# 4           5  HISTORIC NEON -11878155.0351  4175020.6301
# ..        ...            ...            ...           ...
# 195       196         ORPHAN -11863476.3699  4174194.4676
# 196       197         ORPHAN -11862995.9725  4174132.7624
# 197       198         ORPHAN -11861813.2182  4173958.8439
# 198       199         ORPHAN -11861518.1883  4173939.4629
# 199       200         ORPHAN            NaN           NaN
#
# [200 rows x 4 columns]
