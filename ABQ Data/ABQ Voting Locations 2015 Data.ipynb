# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/Voting2015/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

voting_location_list = response.json()['features']
voting_locations = pd.json_normalize(voting_location_list)
voting_locations.columns = voting_locations.columns.str.lstrip("attributes.")

# %%
voting_locations
# Out:
#     OBJECTID                                         name  \
# 0          1           City of Albuquerque Records Center
# 1          2                     Office of the City Clerk
# 2          3                98th and Central (Co. rental)
# 3          4                   West Mesa Community Center
# 4          5                     Alamosa Community Center
# 5          6  North Domingo Baca Multigenerational Center
# 6          7     Don Newton/Taylor Ranch Community Center
# 7          8                            Veterans Memorial
# 8          9                               Daskalos Plaza
# 9         10             Montgomery Crossing (Co. rental)
# 10        11                                Caracol Plaza
# 11        12        Manzano Mesa Multigenerational Center
# 12        13                  Chaparral Elementary School
# 13        14                           Ladera Golf Course
# 14        15                       Painted Sky Elementary
# ...
