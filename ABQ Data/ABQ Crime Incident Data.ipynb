# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/APD_Incidents/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

crime_incident_list = response.json()['features']
crime_incidents = pd.json_normalize(crime_incident_list)
crime_incidents.columns = crime_incidents.columns.str.lstrip("attributes.")

# %%
crime_incidents
# Out:
#        OBJECTID                         BlockAddress      IncidentType  \
# 0      12449065            2800 BLOCK CARLISLE BL NE  TRAFF ACC NO INJ
# 1      12449066             5500 BLOCK WYOMING BL NE    SUSP PERS/VEHS
# 2      12449067               900 BLOCK EUBANK BL NE       DISTURBANCE
# 3      12449068           1100 BLOCK ZENA LONA ST NE    SUSP PERS/VEHS
# 4      12449069           1600 BLOCK JUAN TABO BL NE       DISTURBANCE
# ...         ...                                  ...               ...
# 29995  12479060  LA SALA GRANDE NE / LA CAMILA RD NE    ONSITE TRAFFIC
# 29996  12479061     CARRIAGE RD NE / LOUISIANA BL NE    ONSITE TRAFFIC
# 29997  12479062                   2200 BLOCK Q ST NE    SUSP PERS/VEHS
# 29998  12479063               8200 BLOCK SPAIN RD NE    SUSP PERS/VEHS
# 29999  12479064   4500 BLOCK DOUGLAS MACARTHUR RD NE    ONSITE TRAFFIC
#
#             ReportDateTime    geometry.x    geometry.y
# 0      2022-05-13 02:22:14 -1.186712e+07  4.179245e+06
# 1      2022-05-13 18:57:03 -1.186129e+07  4.183326e+06
# 2      2022-05-13 01:27:29 -1.185915e+07  4.175751e+06
# 3      2022-05-13 22:58:30 -1.185661e+07  4.176264e+06
# 4      2022-05-13 20:15:47 -1.185724e+07  4.177380e+06
# ...                    ...           ...           ...
# 29995  2022-02-17 09:22:29 -1.186101e+07  4.179931e+06
# 29996  2022-02-17 12:20:32 -1.186317e+07  4.182219e+06
# 29997  2022-02-17 14:53:10 -1.186301e+07  4.177843e+06
# 29998  2022-02-17 14:00:02 -1.186136e+07  4.182920e+06
# 29999  2022-02-17 21:03:21 -1.186594e+07  4.181435e+06
#
# [30000 rows x 6 columns]
