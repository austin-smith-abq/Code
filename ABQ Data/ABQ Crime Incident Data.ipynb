# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/APD_Incidents/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

crime_incident_list = response.json()['features']
crime_incidents = pd.json_normalize(crime_incident_list)
crime_incidents.columns = crime_incidents.columns.str.lstrip("attributes.")

# %%
crime_incidents
# Out:
#        OBJECTID                  BlockAddress      IncidentType  \
# 0      13037869     2800 BLOCK CARLISLE BL NE  TRAFF ACC NO INJ
# 1      13037870      5500 BLOCK WYOMING BL NE    SUSP PERS/VEHS
# 2      13037871        900 BLOCK EUBANK BL NE       DISTURBANCE
# 3      13037872    1100 BLOCK ZENA LONA ST NE    SUSP PERS/VEHS
# 4      13037873    1600 BLOCK JUAN TABO BL NE       DISTURBANCE
# ...         ...                           ...               ...
# 29995  13067864  9100 BLOCK BLUE MEADOW TL SW    FAMILY DISPUTE
# 29996  13067865  6600 BLOCK HONEYLOCUST AV NW       DISTURBANCE
# 29997  13067866         300 BLOCK COORS BL NW   ARMED ROB INDIV
# 29998  13067867       5300 BLOCK EUBANK BL NE  FIGHT INPROGRESS
# 29999  13067868    10100 BLOCK BALDWIN AV NE        DISTURBANCE
#
#             ReportDateTime    geometry.x    geometry.y
# 0      2022-05-13 02:22:14 -1.186712e+07  4.179245e+06
# 1      2022-05-13 18:57:03 -1.186129e+07  4.183326e+06
# 2      2022-05-13 01:27:29 -1.185915e+07  4.175751e+06
# 3      2022-05-13 22:58:30 -1.185661e+07  4.176264e+06
# 4      2022-05-13 20:15:47 -1.185724e+07  4.177380e+06
# ...                    ...           ...           ...
# 29995  2022-02-21 22:02:19 -1.188167e+07  4.167464e+06
# 29996  2022-02-21 23:04:59 -1.187940e+07  4.176412e+06
# 29997  2022-02-21 21:06:17 -1.187898e+07  4.175205e+06
# 29998  2022-02-21 01:13:00 -1.185924e+07  4.182779e+06
# 29999  2022-02-21 01:06:45 -1.185898e+07  4.177917e+06
#
# [30000 rows x 6 columns]

# %%
from janitor import clean_names

# %%
crime_incidents = clean_names(crime_incidents)

# %%
test = crime_incidents[1:1000]

# %%
test
# Out:
#      objectid                     blockaddress      incidenttype  \
# 1    13037870         5500 BLOCK WYOMING BL NE    SUSP PERS/VEHS
# 2    13037871           900 BLOCK EUBANK BL NE       DISTURBANCE
# 3    13037872       1100 BLOCK ZENA LONA ST NE    SUSP PERS/VEHS
# 4    13037873       1600 BLOCK JUAN TABO BL NE       DISTURBANCE
# 5    13037874   400 BLOCK WESTERN SKIES DR SE        DISTURBANCE
# ..        ...                              ...               ...
# 995  13038864           6300 BLOCK COORS BL NW      TRAFFIC STOP
# 996  13038865  EAGLE RANCH RD NW / COORS BL NW      TRAFFIC STOP
# 997  13038866           3200 BLOCK COORS BL NW      TRAFFIC STOP
# 998  13038867       10000 BLOCK ARTEMSIA AV SW    ONSITE TRAFFIC
# 999  13038868            400 BLOCK YUCCA DR NW  ONSITE SUSPICIOU
#
#           reportdatetime    geometry_x    geometry_y
# 1    2022-05-13 18:57:03 -1.186129e+07  4.183326e+06
# 2    2022-05-13 01:27:29 -1.185915e+07  4.175751e+06
# 3    2022-05-13 22:58:30 -1.185661e+07  4.176264e+06
# 4    2022-05-13 20:15:47 -1.185724e+07  4.177380e+06
# 5    2022-05-13 07:44:01 -1.185648e+07  4.172747e+06
# ..                   ...           ...           ...
# 995  2022-01-14 15:21:28 -1.187562e+07  4.185350e+06
# 996  2022-01-14 15:25:25 -1.187486e+07  4.187615e+06
# 997  2022-01-14 22:30:37 -1.187797e+07  4.180000e+06
# 998  2022-01-14 18:05:02           NaN           NaN
# 999  2022-01-14 01:08:30 -1.187785e+07  4.175992e+06
#
# [999 rows x 6 columns]

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://xzmoyttqfkxyzz:78c440957ebc992e3d21955483942dc3b7d3a5eb73bc92dc572efd1ea80acf56@ec2-3-222-74-92.compute-1.amazonaws.com:5432/dau4n2mim2itju')
test.to_sql('apd_crime_incidents', engine)
# Out:
# 999
