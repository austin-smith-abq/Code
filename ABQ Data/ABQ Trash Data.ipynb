# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/SolidWaste/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"false","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

trash_list = response.json()['features']
trashs = pd.json_normalize(trash_list)
trashs.columns = trashs.columns.str.lstrip("attributes.")

# %%
trashs
# Out:
#      OBJECTID      DAY_     RA
# 0         532    Friday  RA01F
# 1         533    Friday  RA01F
# 2         534    Friday  RA01F
# 3         535    Friday  RA01F
# 4         536    Friday  RA01F
# ..        ...       ...    ...
# 995      1527  Thursday  RA06H
# 996      1528  Thursday  RA06H
# 997      1529  Thursday  RA06H
# 998      1530  Thursday  RA06H
# 999      1531  Thursday  RA06H
#
# [1000 rows x 3 columns]
