# %%
import requests
import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/BuildingPermits/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","returnDistinctValues":"false","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

building_permit_list = response.json()['features']
building_permits = pd.json_normalize(building_permit_list)
building_permits.columns = building_permits.columns.str.lstrip("attributes.")

# %%
building_permits
# Out:
#      OBJECTID   PermitNumber     DateIssued    DateEntered  \
# 0           1  BP-2016-00029  1478649600000 -2208988800000
# 1           2  BP-2016-00030  1475193600000 -2208988800000
# 2           3  BP-2016-00031  1483574400000 -2208988800000
# 3           4  BP-2016-00050  1477612800000 -2208988800000
# 4           5  BP-2016-00069  1476057600000 -2208988800000
# ..        ...            ...            ...            ...
# 995       996      200990118  1244073600000  1232582400000
# 996       997      200990119  1253577600000  1232582400000
# 997       998      200990120  1237766400000  1232582400000
# 998       999      200990121  1235347200000  1232582400000
# 999      1000      200990122  1235433600000  1232582400000
#
#          CalculatedAddress                                    FreeFormAddress  \
# 0    770 JUAN TABO BLVD NE               770 JUAN TABO BLVD NE           F-22
# 1         3821 SIMMS AV SE            3821 SIMMS AVE SE                  L-17
# ...
