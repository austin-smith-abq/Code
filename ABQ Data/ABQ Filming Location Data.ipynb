# %%
import requests

import pandas as pd
import json

url = "https://coagisweb.cabq.gov/arcgis/rest/services/public/FilmLocations/MapServer/0/query"

querystring = {"where":"1=1","text":"","objectIds":"","time":"","geometry":"","geometryType":"esriGeometryEnvelope","inSR":"","spatialRel":"esriSpatialRelIntersects","relationParam":"","outFields":"*","returnGeometry":"true","maxAllowableOffset":"","geometryPrecision":"","outSR":"","returnIdsOnly":"false","returnCountOnly":"false","orderByFields":"","groupByFieldsForStatistics":"","outStatistics":"","returnZ":"false","returnM":"false","gdbVersion":"","f":"pjson"}

headers = {'user-agent': 'vscode-restclient'}

response = requests.request("GET", url, headers=headers, params=querystring)

film_list = response.json()['features']
films = pd.json_normalize(film_list)
films.columns = films.columns.str.lstrip("attributes.")

# %%
films
# Out:
#       OBJECTID                    Title       Type  \
# 0         4474                     0000      Movie
# 1         4475                     0000      Movie
# 2         4476                     0000      Movie
# 3         4477                     0000      Movie
# 4         4478                     0000      Movie
# ...        ...                      ...        ...
# 1556      6030  IDR: Where we are when       Movie
# 1557      6031  IDR: Where we are when       Movie
# 1558      6032      Katie Says Goodbye       Movie
# 1559      6033                Preacher   TV Series
# 1560      6034                Preacher   TV Series
#
#                                                IMDbLink  \
# 0                  http://www.imdb.com/title/tt1710927/
# 1                  http://www.imdb.com/title/tt1710927/
# 2                  http://www.imdb.com/title/tt1710927/
# 3                  http://www.imdb.com/title/tt1710927/
# 4                  http://www.imdb.com/title/tt1710927/
# ...
